# %% [markdown]
# ![image.png](attachment:8e7dd053-b2c7-4fa8-a174-27b81a389b6f.png)

# %% [markdown]
# ![image.png](attachment:4d996118-22ce-4b00-9265-c87547c2d275.png)

# %% [markdown]
# ![image.png](attachment:cb062f6c-ff10-46d6-b83c-e548e5a786a4.png)

# %% [markdown]
# ![image.png](attachment:5f8100b0-777b-4da0-8b4f-dae28f6b73f5.png)

# %% [markdown]
# ![image.png](attachment:9b3dc6a9-93d0-426c-bc25-a1b38920b206.png)

# %% [markdown]
# ![image.png](attachment:925143bd-869a-4014-b814-6c47bedf4acb.png)

# %% [markdown]
# ![image.png](attachment:aa8aabf8-4aac-482f-8a61-e82642ce5e62.png)

# %% [markdown]
# ![image.png](attachment:c832ce7b-2ac0-4297-a10f-54cc8ab20812.png)

# %% [markdown]
# ![image.png](attachment:c8b68076-8d97-461a-9ee8-5f97c72a284f.png)

# %% [markdown]
# ![image.png](attachment:ed95a4fd-3204-4e17-b222-11ecc2178edd.png)

# %% [markdown]
# ![image.png](attachment:b1b25945-25de-4a14-99e7-3ed0e12eda72.png)

# %% [markdown]
# ![image.png](attachment:b720fb76-66fc-436a-a395-157a6423e9b2.png)

# %% [markdown]
# ![image.png](attachment:e2603394-7741-4bac-8b6d-8d31febe5563.png)

# %% [markdown]
# ![image.png](attachment:f2d2fd88-abdf-4c6c-a654-9c839bc498c8.png)

# %% [markdown]
# ![image.png](attachment:a8e4770c-a1ac-4db3-9534-153f93bc610f.png)

# %% [markdown]
# ![image.png](attachment:b124e5b9-caef-4ad9-9faa-cd8167582daa.png)
